# %% [markdown]
# # NLTK

# %%
import nltk
from nltk import word_tokenize
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /home/kshku/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = "Natural language processing is amazing!"

# %%
tokens = word_tokenize(text)

# %%
tokens
# Out:
# ['Natural', 'language', 'processing', 'is', 'amazing', '!']

# %% [markdown]
# # SpaCy

# %%
import spacy
#!python -m spacy download en_core_web_sm

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "Elon musk Founded SpaceX in 2002"

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text, ent.label)
# Out:
# Founded SpaceX 380
# 2002 391

# %% [markdown]
# # TextBlob

# %%
from textblob import TextBlob

# %%
text = "I love Python. It is so powerful!"

# %%
blob = TextBlob(text)

# %%
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.4375, subjectivity=0.8)

# %% [markdown]
# # Scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = ["NLP is amazing", "I love learning NLP"]
vectorizer = TfidfVectorizer()

# %%
x = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['amazing', 'is', 'learning', 'love', 'nlp'], dtype=object)

# %%
x.toarray()
# Out:
# array([[0.6316672 , 0.6316672 , 0.        , 0.        , 0.44943642],
#        [0.        , 0.        , 0.6316672 , 0.6316672 , 0.44943642]])

# %% [markdown]
# # Transformers

# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
ans = generator("Artificial Intelligence is", max_length=30)
ans
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence is a new area of research at the University of California at San Diego, where he works with students on artificial intelligence.\n\nHe and his colleagues found that their research showed that the amount of processing power that a human would need to process a single sentence would be the same as the amount of processing power a human would need to process a single sentence. The findings also showed that the amount of processing power of machines that could process text would be much higher than the amount of processing power a human would need to process text. These results are published in the journal Nature Communications.\n\n"It\'s not just that we have less processing power, but that we have a more efficient processing power that we can process more sentences," says Martin. "It\'s that we can have more processing power, more languages, more processing power than we do now."\n\nIn a similar experiment, their study of artificial intelligence took place on a small but dynamic world. The simulation simulated a world in which humans were capable of working together to solve problems. This is not the world you see in the movies, but it is a world where a human can be trained to solve problems based on the ability to solve problems.\n\nThe researchers found that the amount of processing power that a human would need'}]

# %%
print(ans[0]['generated_text'])
# Out:
# Artificial Intelligence is a new area of research at the University of California at San Diego, where he works with students on artificial intelligence.
#
# He and his colleagues found that their research showed that the amount of processing power that a human would need to process a single sentence would be the same as the amount of processing power a human would need to process a single sentence. The findings also showed that the amount of processing power of machines that could process text would be much higher than the amount of processing power a human would need to process text. These results are published in the journal Nature Communications.
#
# "It's not just that we have less processing power, but that we have a more efficient processing power that we can process more sentences," says Martin. "It's that we can have more processing power, more languages, more processing power than we do now."
#
# In a similar experiment, their study of artificial intelligence took place on a small but dynamic world. The simulation simulated a world in which humans were capable of working together to solve problems. This is not the world you see in the movies, but it is a world where a human can be trained to solve problems based on the ability to solve problems.
#
# The researchers found that the amount of processing power that a human would need
